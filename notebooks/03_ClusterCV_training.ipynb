# %% [markdown]
# # Training with ClusterCV

# %%
import sys

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from tqdm import tqdm

import clustercv

# %%
# Read data file
data = pd.read_csv("cmpd_activity_tcrd_5.4.1.csv", low_memory=False)
# Filter data
targets = clustercv.filter_data(data, act_type='IC50', min_samples=100)
# Generate features
#n = targets[2]
for i in range(len(targets)):
    n = targets[i]
    print("Target:", n)
    target_data = clustercv.get_target_data(data, n)
    
    # Get features
    features = clustercv.batchECFP(target_data.smiles)
    
    # Cluster features and generate folds
    n_folds = 10
    folds, max_score = clustercv.ClusterCV(features, n_folds=10)
    
    # Train a random forest
    rf = RandomForestRegressor(n_estimators=500, random_state=42, n_jobs=3)
    scores = np.zeros(n_folds)
    r2scores = np.zeros(n_folds)
    n_features = features.shape[1]
    for k in range (n_folds):
        # Get training and testing set
        test_index = np.where(folds == k)[0]
        train_index = np.where(folds != k)[0]
        # Get train and test samples
        X_test = features[test_index, :]
        X_train = features[train_index, :]
        y_test = target_data.act_value.iloc[test_index]
        y_train = target_data.act_value.iloc[train_index]
        # Run Model
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_test)
        scores[k] = mean_squared_error(y_test, y_pred)
        r2scores[k] = r2_score(y_test, y_pred)
    print("R2: %0.2f (+/- %0.2f)" % (
        r2scores.mean(), r2scores.std() * 2))
    print("MSE: %0.2f (+/- %0.2f)" % (
        scores.mean(), scores.std() * 2))
    print()
# Out:
# Target: 27
# Number of clusters: 43
# R2: -0.41 (+/- 1.79)
# MSE: 0.30 (+/- 0.36)
#
# Target: 36
# Number of clusters: 45
# R2: 0.01 (+/- 1.12)
# MSE: 0.40 (+/- 0.52)
#
# Target: 39
# Number of clusters: 41
# R2: -1.53 (+/- 4.63)
# MSE: 0.52 (+/- 0.44)
#
# Target: 42
# Number of clusters: 120
# R2: 0.47 (+/- 0.52)
# MSE: 0.44 (+/- 0.64)
#
# Target: 59
# Number of clusters: 103
# R2: -0.06 (+/- 0.76)
# MSE: 0.28 (+/- 0.32)
#
# Target: 61
# Number of clusters: 154
# R2: -0.02 (+/- 0.78)
# MSE: 0.76 (+/- 0.80)
#
# Target: 77
# Number of clusters: 133
# R2: -0.36 (+/- 1.34)
# MSE: 0.33 (+/- 0.40)
#
# Target: 103
# Number of clusters: 242
# R2: 0.24 (+/- 0.46)
# MSE: 0.35 (+/- 0.22)
#
# Target: 104
# Number of clusters: 53
# R2: -1.33 (+/- 8.16)
# MSE: 0.44 (+/- 0.45)
#
# Target: 139
# Number of clusters: 66
# R2: -0.09 (+/- 1.30)
# MSE: 0.01 (+/- 0.01)
#
# Target: 144
# Number of clusters: 1011
# R2: 0.40 (+/- 0.19)
# MSE: 0.49 (+/- 0.24)
#
# Target: 150
# Number of clusters: 50
# R2: -0.52 (+/- 1.58)
# MSE: 0.91 (+/- 0.76)
#
# Target: 153
# Number of clusters: 392
# R2: 0.27 (+/- 0.42)
# MSE: 0.49 (+/- 0.28)
#
# Target: 253
# Number of clusters: 425
# R2: 0.30 (+/- 0.36)
# MSE: 0.21 (+/- 0.12)
#
# Target: 411
# Number of clusters: 1535
# R2: 0.54 (+/- 0.17)
# MSE: 0.16 (+/- 0.05)
#
# Target: 430
# Number of clusters: 61
# R2: 0.17 (+/- 0.58)
# MSE: 0.64 (+/- 1.02)
#
# Target: 443
# Number of clusters: 47
# R2: 0.12 (+/- 0.84)
# MSE: 0.44 (+/- 0.48)
#
# Target: 444
# Number of clusters: 127
# R2: 0.04 (+/- 0.42)
# MSE: 0.17 (+/- 0.22)
#
# Target: 448
# Number of clusters: 156
# R2: 0.11 (+/- 0.39)
# MSE: 0.32 (+/- 0.16)
#
# Target: 469
# Number of clusters: 143
# R2: -0.11 (+/- 0.57)
# MSE: 0.42 (+/- 0.28)
#
# Target: 476
# Number of clusters: 182
# R2: 0.27 (+/- 0.56)
# MSE: 0.26 (+/- 0.15)
#
# Target: 483
# Number of clusters: 179
# R2: 0.21 (+/- 0.29)
# MSE: 0.62 (+/- 0.50)
#
# Target: 521
# Number of clusters: 350
# R2: 0.23 (+/- 0.24)
# MSE: 0.45 (+/- 0.32)
#
# Target: 570
# Number of clusters: 459
# R2: 0.29 (+/- 0.26)
# MSE: 0.13 (+/- 0.06)
#
# Target: 616
# Number of clusters: 94
# R2: -0.00 (+/- 0.98)
# MSE: 0.08 (+/- 0.11)
#
# Target: 756
# Number of clusters: 475
# R2: 0.11 (+/- 0.53)
# MSE: 0.54 (+/- 0.34)
#
# Target: 862
# Number of clusters: 218
# R2: 0.27 (+/- 0.32)
# MSE: 0.28 (+/- 0.19)
#
# Target: 875
# Number of clusters: 155
# R2: -0.24 (+/- 0.60)
# MSE: 0.54 (+/- 0.46)
#
# Target: 996
# Number of clusters: 37
# R2: -4.22 (+/- 23.98)
# MSE: 0.64 (+/- 0.83)
#
# Target: 1028
# Number of clusters: 119
# R2: -0.09 (+/- 0.49)
# MSE: 0.69 (+/- 0.53)
#
# Target: 1064
# Number of clusters: 412
# R2: 0.26 (+/- 0.18)
# MSE: 0.49 (+/- 0.16)
#
# Target: 1168
# Number of clusters: 179
# R2: 0.35 (+/- 0.34)
# MSE: 0.27 (+/- 0.17)
#
# Target: 1177
# Number of clusters: 23
# R2: -0.57 (+/- 1.63)
# MSE: 0.18 (+/- 0.48)
#
# Target: 1232
# Number of clusters: 65
# R2: 0.08 (+/- 0.78)
# MSE: 0.19 (+/- 0.17)
#
# Target: 1326
# Number of clusters: 31
# R2: 0.19 (+/- 0.92)
# MSE: 0.19 (+/- 0.31)
#
# Target: 1556
# Number of clusters: 56
# R2: -0.56 (+/- 1.33)
# MSE: 0.46 (+/- 0.66)
#
# Target: 1565
# Number of clusters: 20
# R2: -1.73 (+/- 7.28)
# MSE: 0.94 (+/- 1.42)
#
# Target: 1566
# Number of clusters: 20
# R2: -5.65 (+/- 17.61)
# MSE: 0.39 (+/- 0.92)
#
# Target: 1574
# Number of clusters: 597
# R2: 0.43 (+/- 0.20)
# MSE: 0.35 (+/- 0.24)
#
# Target: 1583
# Number of clusters: 2695
# R2: 0.52 (+/- 0.08)
# MSE: 0.30 (+/- 0.05)
#
# Target: 1584
# Number of clusters: 175
# R2: 0.38 (+/- 0.43)
# MSE: 0.31 (+/- 0.26)
#
# Target: 1602
# Number of clusters: 79
# R2: 0.12 (+/- 0.93)
# MSE: 0.32 (+/- 0.28)
#
# Target: 1625
# Number of clusters: 574
# R2: 0.44 (+/- 0.17)
# MSE: 0.21 (+/- 0.18)
#
# Target: 1628
# Number of clusters: 127
# R2: 0.35 (+/- 0.62)
# MSE: 0.16 (+/- 0.19)
#
# Target: 1629
# Number of clusters: 155
# R2: 0.31 (+/- 0.93)
# MSE: 0.27 (+/- 0.60)
#
# Target: 1630
# Number of clusters: 299
# R2: 0.25 (+/- 0.49)
# MSE: 0.30 (+/- 0.41)
#
# Target: 1635
# Number of clusters: 51
# R2: -0.40 (+/- 3.01)
# MSE: 0.36 (+/- 0.94)
#
# Target: 1678
# Number of clusters: 80
# R2: 0.13 (+/- 1.02)
# MSE: 0.21 (+/- 0.14)
#
# Target: 1691
# Number of clusters: 25
# R2: -0.99 (+/- 3.50)
# MSE: 0.56 (+/- 0.86)
#
# Target: 1707
# Number of clusters: 42
# R2: -0.02 (+/- 0.82)
# MSE: 0.41 (+/- 0.59)
#
# Target: 1709
# Number of clusters: 741
# R2: 0.50 (+/- 0.15)
# MSE: 0.51 (+/- 0.16)
#
# Target: 1729
# Number of clusters: 92
# R2: 0.00 (+/- 0.78)
# MSE: 0.59 (+/- 0.64)
#
# Target: 1738
# Number of clusters: 38
# R2: -0.55 (+/- 2.90)
# MSE: 0.21 (+/- 0.38)
#
# Target: 1759
# Number of clusters: 489
# R2: 0.38 (+/- 0.45)
# MSE: 0.48 (+/- 0.38)
#
# Target: 1816
# Number of clusters: 387
# R2: 0.25 (+/- 0.37)
# MSE: 0.38 (+/- 0.24)
#
# Target: 1917
# Number of clusters: 60
# R2: -0.35 (+/- 0.95)
# MSE: 0.49 (+/- 0.89)
#
# Target: 1936
# Number of clusters: 79
# R2: 0.16 (+/- 0.64)
# MSE: 0.26 (+/- 0.25)
#
# Target: 1951
# Number of clusters: 41
# R2: -0.63 (+/- 3.55)
# MSE: 0.43 (+/- 0.52)
#
# Target: 1977
# Number of clusters: 21
# R2: -1.40 (+/- 3.22)
# MSE: 0.57 (+/- 1.18)
#
# Target: 1981
# Number of clusters: 20
# R2: -2.17 (+/- 6.11)
# MSE: 0.58 (+/- 1.00)
#
# Target: 1990
# Number of clusters: 139
# R2: 0.11 (+/- 0.55)
# MSE: 0.39 (+/- 0.26)
#
# Target: 2122
# Number of clusters: 59
# R2: 0.03 (+/- 0.53)
# MSE: 0.16 (+/- 0.14)
#
# Target: 2126
# Number of clusters: 36
# R2: -0.52 (+/- 1.80)
# MSE: 0.34 (+/- 0.47)
#
# Target: 2142
# Number of clusters: 43
# R2: 0.32 (+/- 0.67)
# MSE: 0.27 (+/- 0.41)
#
# Target: 2182
# Number of clusters: 21
# R2: -5.15 (+/- 13.71)
# MSE: 0.48 (+/- 1.00)
#
# Target: 2229
# Number of clusters: 135
# R2: 0.41 (+/- 0.53)
# MSE: 0.61 (+/- 0.54)
#
# Target: 2231
# Number of clusters: 200
# R2: 0.51 (+/- 0.50)
# MSE: 0.38 (+/- 0.39)
#
# Target: 2281
# Number of clusters: 61
# R2: 0.27 (+/- 0.92)
# MSE: 0.53 (+/- 0.88)
#
# Target: 2292
# Number of clusters: 231
# R2: 0.36 (+/- 0.45)
# MSE: 0.21 (+/- 0.13)
#
# Target: 2298
# Number of clusters: 530
# R2: 0.62 (+/- 0.37)
# MSE: 0.33 (+/- 0.28)
#
# Target: 2300
# Number of clusters: 26
# R2: -0.84 (+/- 2.43)
# MSE: 0.62 (+/- 0.77)
#
# Target: 2303
# Number of clusters: 74
# R2: -0.07 (+/- 0.27)
# MSE: 0.43 (+/- 0.41)
#
# Target: 2343
# Number of clusters: 241
# R2: 0.48 (+/- 0.43)
# MSE: 0.24 (+/- 0.14)
#
# Target: 2360
# Number of clusters: 78
# R2: -0.32 (+/- 1.36)
# MSE: 0.16 (+/- 0.21)
#
# Target: 2377
# Number of clusters: 86
# R2: -0.50 (+/- 1.08)
# MSE: 0.78 (+/- 0.98)
#
# Target: 2380
# Number of clusters: 124
# R2: 0.03 (+/- 0.65)
# MSE: 0.75 (+/- 0.82)
#
# Target: 2442
# Number of clusters: 44
# R2: -0.10 (+/- 1.37)
# MSE: 0.45 (+/- 1.07)
#
# Target: 2582
# Number of clusters: 64
# R2: -0.09 (+/- 0.36)
# MSE: 0.42 (+/- 0.49)
#
# Target: 2647
# Number of clusters: 74
# R2: -0.09 (+/- 0.73)
# MSE: 0.45 (+/- 0.25)
#
# Target: 2741
# Number of clusters: 227
# R2: 0.43 (+/- 0.23)
# MSE: 0.34 (+/- 0.31)
#
# Target: 2754
# Number of clusters: 439
# R2: 0.49 (+/- 0.25)
# MSE: 0.22 (+/- 0.10)
#
# Target: 2770
# Number of clusters: 138
# R2: -0.04 (+/- 0.40)
# MSE: 0.45 (+/- 0.40)
#
# Target: 2781
# Number of clusters: 355
# R2: 0.11 (+/- 0.93)
# MSE: 0.30 (+/- 0.26)
#
# Target: 2854
# Number of clusters: 623
# R2: 0.30 (+/- 0.37)
# MSE: 0.26 (+/- 0.19)
#
# Target: 2887
# Number of clusters: 365
# R2: 0.15 (+/- 0.43)
# MSE: 0.29 (+/- 0.17)
#
# Target: 2964
# Number of clusters: 27
# R2: -2.99 (+/- 16.37)
# MSE: 0.14 (+/- 0.12)
#
# Target: 3005
# Number of clusters: 148
# R2: -0.17 (+/- 0.69)
# MSE: 0.74 (+/- 0.89)
#
# Target: 3015
# Number of clusters: 383
# R2: 0.33 (+/- 0.29)
# MSE: 0.28 (+/- 0.12)
#
# Target: 3104
# Number of clusters: 730
# R2: 0.52 (+/- 0.23)
# MSE: 0.27 (+/- 0.11)
#
# Target: 3144
# Number of clusters: 410
# R2: 0.10 (+/- 0.51)
# MSE: 0.22 (+/- 0.18)
#
# Target: 3145
# Number of clusters: 63
# R2: -0.07 (+/- 0.96)
# MSE: 0.18 (+/- 0.17)
#
# Target: 3239
# Number of clusters: 36
# R2: -9.83 (+/- 41.56)
# MSE: 0.56 (+/- 0.78)
#
# Target: 3278
# Number of clusters: 24
# R2: -0.96 (+/- 4.03)
# MSE: 0.23 (+/- 0.30)
#
# Target: 3307
# Number of clusters: 324
# R2: 0.41 (+/- 0.48)
# MSE: 0.47 (+/- 0.27)
#
# Target: 3354
# Number of clusters: 22
# R2: -0.66 (+/- 2.34)
# MSE: 0.73 (+/- 1.78)
#
# Target: 3358
# Number of clusters: 22
# R2: -6.28 (+/- 19.19)
# MSE: 1.08 (+/- 1.29)
#
# Target: 3446
# Number of clusters: 776
# R2: 0.49 (+/- 0.21)
# MSE: 0.42 (+/- 0.25)
#
# Target: 3460
# Number of clusters: 214
# R2: 0.23 (+/- 0.28)
# MSE: 0.10 (+/- 0.07)
#
# Target: 3552
# Number of clusters: 188
# R2: -0.03 (+/- 0.61)
# MSE: 0.46 (+/- 0.44)
#
# Target: 3718
# Number of clusters: 33
# R2: -0.28 (+/- 0.93)
# MSE: 0.50 (+/- 0.38)
#
# Target: 3915
# Number of clusters: 46
# R2: -1.21 (+/- 6.75)
# MSE: 0.25 (+/- 0.33)
#
# Target: 4024
# Number of clusters: 218
# R2: 0.32 (+/- 0.40)
# MSE: 0.28 (+/- 0.28)
#
# Target: 4068
# Number of clusters: 46
# R2: -0.91 (+/- 1.97)
# MSE: 0.56 (+/- 1.00)
#
# Target: 4119
# Number of clusters: 81
# R2: 0.46 (+/- 0.46)
# MSE: 0.17 (+/- 0.15)
#
# Target: 4120
# Number of clusters: 42
# R2: -0.65 (+/- 2.95)
# MSE: 0.32 (+/- 0.42)
#
# Target: 4161
# Number of clusters: 203
# R2: 0.57 (+/- 0.29)
# MSE: 0.24 (+/- 0.23)
#
# Target: 4215
# Number of clusters: 358
# R2: 0.31 (+/- 0.39)
# MSE: 0.35 (+/- 0.16)
#
# Target: 4443
# Number of clusters: 144
# R2: 0.18 (+/- 0.70)
# MSE: 0.58 (+/- 0.48)
#
# Target: 4592
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-fd46fd03896e> in <module>
#      15     # Cluster features and generate folds
#      16     n_folds = 10
# ---> 17     folds, max_score = clustercv.ClusterCV(features, n_folds=10)
#      18
#      19     # Train a random forest
#
# ~/Projects/ClusterCV/clustercv.py in ClusterCV(features, linkage, n_folds)
#      82                                              affinity='precomputed',
#      83                                              linkage=linkage)
# ---> 84         clustering = clustering.fit(distmatrix)
#      85         scores[i] = silhouette_score(distmatrix, labels=clustering.labels_,
#      86                                      metric='precomputed')
#
# ~/Software/miniconda/lib/python3.6/site-packages/sklearn/cluster/hierarchical.py in fit(self, X, y)
#     828             memory.cache(tree_builder)(X, connectivity,
#     829                                        n_clusters=n_clusters,
# --> 830                                        **kwargs)
#     831         # Cut the tree
#     832         if compute_full_tree:
#
# ~/Software/miniconda/lib/python3.6/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     327
#     328     def __call__(self, *args, **kwargs):
# --> 329         return self.func(*args, **kwargs)
#     330
#     331     def call_and_shelve(self, *args, **kwargs):
#
# ~/Software/miniconda/lib/python3.6/site-packages/sklearn/cluster/hierarchical.py in _single_linkage(*args, **kwargs)
#     592 def _single_linkage(*args, **kwargs):
#     593     kwargs['linkage'] = 'single'
# --> 594     return linkage_tree(*args, **kwargs)
#     595
#     596
#
# ~/Software/miniconda/lib/python3.6/site-packages/sklearn/cluster/hierarchical.py in linkage_tree(X, connectivity, n_components, n_clusters, linkage, affinity, return_distance)
#     468             i, j = np.triu_indices(X.shape[0], k=1)
#     469             X = X[i, j]
# --> 470         out = hierarchy.linkage(X, method=linkage, metric=affinity)
#     471         children_ = out[:, :2].astype(np.int)
#     472
#
# ~/Software/miniconda/lib/python3.6/site-packages/scipy/cluster/hierarchy.py in linkage(y, method, metric, optimal_ordering)
#     718
#     719     if method == 'single':
# --> 720         result = _hierarchy.mst_single_linkage(y, n)
#     721     elif method in ['complete', 'average', 'weighted', 'ward']:
#     722         result = _hierarchy.nn_chain(y, n, method_code)
#
# _hierarchy.pyx in scipy.cluster._hierarchy.mst_single_linkage()
#
# ~/Software/miniconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py in argsort(a, axis, kind, order)
#     824
#     825
# --> 826 def argsort(a, axis=-1, kind='quicksort', order=None):
#     827     """
#     828     Returns the indices that would sort an array.
#
# KeyboardInterrupt:
